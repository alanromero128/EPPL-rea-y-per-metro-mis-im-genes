# %% [markdown]
# <a href="https://colab.research.google.com/github/alanromero128/EPPL-rea-y-per-metro-mis-im-genes/blob/main/El_profe_circulo_Alan_Romero_0124.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Alan Romero NL =47 Fecha:25/mar/2026 ☁
# ---
# # Calcular area y perimetro de un circulo
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/alanromero128/EPPL-rea-y-per-metro-mis-im-genes/refs/heads/main/area_circulo.JPG)
#
#
# ---
# ## Formula para calcular el area
# $A=\pi*r^2$
#
# ---
# ## Forula para calcular perimetro
# $P=2*\pi*r$
# ## Datos de entrada
# $r$ ?
#
#
# ---
#
#
# ## Diagrama de flujo de lucidchart
# ![Logo de Markdown](https://raw.githubusercontent.com/alanromero128/EPPL-rea-y-per-metro-mis-im-genes/refs/heads/main/DF%20Area%20perimetro%20circulo.png)

# %%
# Calcular area y perimetro de un circulo
# Variables P,A,r
# Formulas A = pi*r^2    y   P = 2 * pi * r
# Capturar el valor de r
print("Calcular area y perimetro de un circulo")
r = float(input("Ingrese el valor de radio: "))
import math
A = math.pi * r**2
P = 2 * math.pi * r
print("El area del circulo es: ", A)
print("El perimetro del circulo es: ", P)
print("Alan Romero NL = 47")
# Out:
# Calcular area y perimetro de un circulo
# Ingrese el valor de radio: 5
# El area del circulo es:  78.53981633974483
# El perimetro del circulo es:  31.41592653589793
# Alan Romero NL = 47

# %% [markdown]
# # Relacion entre codigo y DF en  Tldraw
# ![Logo de Markdown](https://raw.githubusercontent.com/alanromero128/EPPL-rea-y-per-metro-mis-im-genes/refs/heads/main/tldraw%20DF%20y%20%20codigo.png)
